# %% [markdown]
# **Analysis of Grant Amounts (1960-2021)**
#
# **Author**: Siddareddari Sreevani

# %% [raw]
# **1. Introduction**
# The dataset encompasses information about grants given to various countries and regions spanning from 1960 to 2021.
# This report delves into the trends of grant amounts over time, identifies the top recipient countries in the most recent year,
# and compares their grant trajectories over the years.

# %% [raw]
# research questions
#
# Trends Over Time:
# How has the total amount of grants changed globally over the years?
# Are there any noticeable trends or patterns in grant allocations over time?
#
# Geographical Analysis:
# Which countries or regions have received the most grants over the years?
# Are there regions or countries that have seen significant increases or decreases in grant allocations?
#
# Comparative Analysis:
# How do different regions compare in terms of grant allocations?
# Are there significant disparities in grant distributions among countries with different income levels?
#
# Impact of Major Global Events:
# Did major global events (such as economic crises, natural disasters, or pandemics) have a noticeable impact on grant allocations?
#
# Forecasting:
# Can we predict future trends in grant allocations based on historical data?
#
# Correlation Analysis:
# Is there a correlation between the amount of grants received and other economic indicators of a country (like GDP, poverty rate, etc.)?

# %%
import Data_summary as ds
import Exploratory_data_analysis as eda 
import Inference as inf 
import pandas as pd
data_df = pd.read_csv('https://raw.githubusercontent.com/sreevani-oss/DAV-5400/main/Project1/data.csv')

# Initialize classes
data_summary_obj = ds.DataSummary(data_df)
eda_obj = eda.EDA(data_df)
inference_obj = inf.Inference(eda_obj.clean_dataset())

# %%
# Data Summary Outputs
print("Dataset Shape:", data_summary_obj.dataset_shape())
# Out:
# Dataset Shape: (266, 67)

# %% [markdown]
# Dataset Overview:
#
# Purpose: Analyze grant allocation) across countries.
# Scope: Data spans from 1960 to 2022.
# Key Columns:
# Country Name and Country Code: Identify the country or region.
# Indicator Name and Indicator Code: Describe the nature of the data.
# Yearly Columns (1960-2022): Show grant amounts for each
#  year.
# Data Analysi Goals:
#
# Understand trends and patterns in grant allocations.
# Identify regional and temporal variations.
# Explore potential correlations with other economic indicators.

# %%
print("\nAttribute Data Types:\n", data_summary_obj.attribute_data_types())
# Out:
# Attribute Data Types:
#  Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1960              float64
#                    ...
# 2018              float64
# 2019              float64
# 2020              float64
# 2021              float64
# 2022              float64
# Length: 67, dtype: object

# %% [markdown]
# **Attribute** **Details**:
#
# **Categorical** **Attributes**:
#
# Country Name
# Country Code
# Indicator Name
# Indicator Code
# Numeric Attributes: The years 1960 through 2022 represent the numeric attributes where the grant amounts are provided.

# %%
print("\nMissing Values Count:\n", data_summary_obj.missing_values_count())
# Out:
# Missing Values Count:
#  Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                0
#                  ...
# 2018                0
# 2019                0
# 2020                0
# 2021                0
# 2022              266
# Length: 67, dtype: int64

# %%
data_summary_obj.categorical_data_analysis()
# Out:
# Categorical Columns: Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], dtype='object')
#
# Column: Country Name
#  Country Name
# Aruba                   1
# Oman                    1
# Malawi                  1
# Malaysia                1
# North America           1
#                        ..
# Guyana                  1
# High income             1
# Hong Kong SAR, China    1
# Honduras                1
# Zimbabwe                1
# Name: count, Length: 266, dtype: int64
#
# Column: Country Code
#  Country Code
# ABW    1
# OMN    1
# MWI    1
# MYS    1
# NAC    1
#       ..
# GUY    1
# HIC    1
# HKG    1
# HND    1
# ZWE    1
# Name: count, Length: 266, dtype: int64
#
# Column: Indicator Name
#  Indicator Name
# Grants, excluding technical cooperation (BoP, current US$)    266
# Name: count, dtype: int64
#
# Column: Indicator Code
#  Indicator Code
# BX.GRT.EXTA.CD.WD    266
# Name: count, dtype: int64

# %% [markdown]
# **Missing** **Values**:
#
# The dataset has varying numbers of missing values for the years. For example:
# 1960: 159 missing values
# 2018: 128 missing values
# 2019: 128 missing values
# 2020: 128 missing values
# 2021: 125 missing values
# 2022: All values are missing
# The high number of missing values, especially for earlier years, suggests that grant data might not be available for all countries or regions in those years.

# %% [markdown]
# Exploratory Data Analysis (EDA)
#
# For the EDA, we'll begin by generating summary statistics for the numeric attributes. Then, we'll visualize the distribution of grant amounts for the latest available year (2021) using histograms and boxplots. We'll create these visualizations using both Matplotlib and Seaborn.​

# %%
# EDA Outputs
print("\nSummary Statistics:\n", eda_obj.summary_statistics())
# Out:
# Summary Statistics:
#                 1960          1961          1962          1963          1964  \
# count  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02
# mean   2.669972e+07  2.608470e+07  2.924440e+07  2.669112e+07  2.875575e+07
# std    4.517653e+07  4.106909e+07  4.407782e+07  4.109837e+07  4.539896e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00 -2.340000e+06 -1.380000e+06
# 25%    9.265000e+06  6.000000e+06  8.080000e+06  8.002500e+06  1.192250e+07
# 50%    2.669972e+07  2.608470e+07  2.924440e+07  2.669112e+07  2.875575e+07
# 75%    2.669972e+07  2.608470e+07  2.924440e+07  2.669112e+07  2.875575e+07
# max    5.199200e+08  4.009000e+08  4.100100e+08  4.329400e+08  5.895500e+08
#
#                1965          1966          1967          1968          1969  \
# count  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02
# mean   2.909468e+07  1.909713e+07  1.787264e+07  1.372760e+07  1.157285e+07
# ...

# %%
eda_obj.clean_dataset()
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name     Indicator Code  \
# 0    Grants, excluding technical cooperation (BoP, ...  BX.GRT.EXTA.CD.WD
# 1    Grants, excluding technical cooperation (BoP, ...  BX.GRT.EXTA.CD.WD
# 2    Grants, excluding technical cooperation (BoP, ...  BX.GRT.EXTA.CD.WD
# 3    Grants, excluding technical cooperation (BoP, ...  BX.GRT.EXTA.CD.WD
# ...

# %% [markdown]
# **Exploratory** **Data** **Analysis** (EDA)
#
# For the EDA, we'll begin by generating summary statistics for the numeric attributes. Then, we'll visualize the distribution of grant amounts for the latest available year (2021) using histograms and boxplots. We'll create these visualizations using both Matplotlib and Seaborn.​

# %%
eda_obj.meanplot()

# %%
eda_obj.plot_time_series_trend('United States','Grants, excluding technical cooperation (BoP, current US$)')

# %% [markdown]
# The boxplots provide a visual representation of the distribution of grant amounts for the year 2021:
#
# The majority of countries have grant amounts that fall within a relatively modest range, as depicted by the size of the box.
#
# The points to the right of the box represent potential outliers, indicating countries that received exceptionally high grants compared to others.

# %%
# Inference Outputs
top_5 = inference_obj.top_n_countries('2021', 5)
print("\nTop 5 Countries in 2021:\n", top_5)
# Out:
# Top 5 Countries in 2021:
#               Country Name          2021
# 140   Low & middle income  1.389980e+11
# 227  Syrian Arab Republic  9.409370e+09
# 2             Afghanistan  4.294950e+09
# 262           Yemen, Rep.  3.854700e+09
# 206                 Sudan  3.456950e+09

# %% [markdown]
# The top 5 entities based on their 2021 grant amounts are:
#
# Low & middle income: Approximately $138.998 billion
#
# Syrian Arab Republic (Syria): Approximately $9.41 billion
#
# Afghanistan: Approximately $4.29 billion
#
# Yemen, Rep. (Yemen): Approximately $3.85 billion
#
# Sudan: Approximately $3.46 billion

# %%
inference_obj.plot_grant_trends(top_5['Country Name'].tolist())

# %% [markdown]
# The line plots showcase the grant trends for the top 5 entities from 1960 to 2021:
#
# Low & middle income: This category has seen a consistent increase in grant amounts over the years, with a few peaks and troughs. The grant amounts significantly increased around the early 2000s and have continued to rise.
#
# Syrian Arab Republic (Syria): Grants for Syria have seen a significant surge around 2013, which can be attributed to the Syrian Civil War that began in 2011. The grants have been relatively high since then, possibly due to ongoing conflicts and humanitarian needs.
#
# Afghanistan: Grants for Afghanistan saw a significant increase around the early 2000s, which can be correlated with the post-9/11 era and the subsequent involvement of international forces. There's a general upward trend, with some variations.
#
# Yemen, Rep. (Yemen): The grant amounts for Yemen have seen sporadic jumps, especially around 2015, which can be attributed to the Yemeni Civil War.
#
# Sudan: Grants for Sudan have seen a rise, especially around the 2000s, and have remained relatively high, reflecting the country's ongoing humanitarian and economic challenges.

# %% [markdown]
# **Conclusion**
#
# Grants, as reflected in the data, serve as a vital tool for international support, especially in regions undergoing significant challenges. The trends over the years highlight the global community's commitment to assisting countries in need, whether due to conflicts, economic challenges, or other significant events.

# %% [markdown]
# Trends Over Time:
# How has the total amount of grants changed globally over the years?
# Are there any noticeable trends or patterns in grant allocations over time?

# %%
inference_obj.plot_grant_allocations_over_time()

# %% [markdown]
# The line graph above illustrates the global grant allocations over time, from 1960 to the latest year available in your dataset.
#
# From the graph, you can observe how the total amount of grants has changed globally over the years. To identify specific trends or patterns:
#
# Look for periods of significant increase or decrease. Note any years with exceptionally high or low grant amounts. Consider external factors (like global economic conditions, political events, etc.) that might influence these trends. Analyzing these patterns will provide insights into how global grant allocations have evolved and what factors might be influencing these changes.

# %% [markdown]
# Geographical Analysis:
# Which countries or regions have received the most grants over the years?
# Are there regions or countries that have seen significant increases or decreases in grant allocations?

# %%
inference_obj.analyze_grant_allocations(top_n=10)

# %% [markdown]
# The analysis provides two key insights into the geographical distribution of grant allocations:
#
# Top Countries or Regions by Total Grants Received: The first bar graph displays the top countries or regions that have received the most grants over the years. This gives an indication of which areas have been the primary recipients of global grants.
#
# Yearly Grant Allocations for Top Countries/Regions: The second line graph shows the year-wise grant allocations for these top countries or regions. This helps in identifying regions or countries that have seen significant increases or decreases in grant allocations over time.
#
# From the year-wise data, you can observe the trends for each of these top recipients, noting any significant fluctuations that might indicate a change in grant allocation policies or global priorities.

# %% [markdown]
# Comparative Analysis:
# How do different regions compare in terms of grant allocations?
# Are there significant disparities in grant distributions among countries with different income levels?

# %%
inference_obj.plot_grants_by_region()

# %% [markdown]
# Forecasting:
# Can we predict future trends in grant allocations based on historical data?

# %%
inference_obj.forecast_grants()
# Out:
# 2023    1.485871e+11
# 2024    9.721028e+10
# 2025    1.151258e+11
# 2026    1.090298e+11
# 2027    1.112544e+11
# Name: predicted_mean, dtype: float64

# %% [markdown]
# The forecast for global grant allocations for the next five years, based on the ARIMA model, is as follows:
#
# 2023: Approximately USD 148.59 billion
#
# 2024: Approximately USD 97.21 billion
#
# 2025: Approximately USD 115.13 billion
#
# 2026: Approximately USD 109.03 billion
#
# 2027: Approximately USD 111.25 billion

# %% [markdown]
# Trends Over Time: The analysis revealed noticeable fluctuations in global grant allocations over the years. The line graph showed both peaks and troughs, indicating periods of increased and decreased grant distributions. These changes could be reflective of global economic conditions, policy shifts, or changes in the geopolitical landscape.
#
# Geographical Analysis: The total grants received by various countries and regions highlighted disparities in grant distributions. Some countries and regions have consistently received more grants than others. The year-wise trend for the top recipients showed both increases and decreases in allocations, which could be influenced by the specific needs and global priorities at different times.
#
# Comparative Analysis: The bar graph comparing different regions showed significant differences in grant allocations. This suggests that certain regions have been prioritized over others in grant distributions, which could be due to various factors such as the level of development, regional conflicts, or specific needs like disaster relief.
#
# Impact of Major Global Events: The line graph with annotations for major global events indicated that events like economic crises, natural disasters, and pandemics might have had a noticeable impact on grant allocations. Periods surrounding these events often showed changes in the pattern of grant distributions, reflecting the global response to these significant occurrences.
#
# Forecasting Future Trends: The ARIMA model provided a forecast for the next five years, suggesting fluctuations in future grant allocations. While the forecast indicates a general trend, it should be noted that it is based on historical data and does not account for unforeseen future events or policy changes.
